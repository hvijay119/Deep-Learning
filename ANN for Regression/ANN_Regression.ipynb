# %% [markdown]
# # Problem Statement
#
# ### Build a ML Model that predicts the median house price based on 13 socio-economic and property-related features from the Boston Housing dataset.

# %% [markdown]
# ## 1. Import Necessary Libraries

# %%
import numpy as np
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 2. Import Dataset

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step

# %% [markdown]
# ### 3. Data Understanding

# %%
X_train.shape,y_train.shape
# Out:
# ((404, 13), (404,))

# %%
X_test.shape,y_test.shape
# Out:
# ((102, 13), (102,))

# %% [markdown]
# ### 4. Data Preparation

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train.std().round(),X_train.mean().round()
# Out:
# (np.float64(1.0), np.float64(0.0))

# %%
X_test.std().round(),X_test.mean().round()
# Out:
# (np.float64(1.0), np.float64(-0.0))

# %% [markdown]
# ### 5. Model Building

# %%
model = Sequential()

model.add(Dense(64, activation='relu', input_shape=(13,))) #For structured data, use input_shape
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output layer (IMPORTANT)
model.add(Dense(1,))  # No activation → regression

# %%
model.compile(optimizer='adam',loss='mse', metrics=['mae'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ### 6. Model Training || 7. Model Testing || 8. Model Evaluation

# %%
model.fit(X_train, y_train,epochs=100,batch_size=16,validation_split=0.2, verbose=2)
# Out:
# Epoch 1/100
# 21/21 - 7s - 339ms/step - loss: 550.8104 - mae: 21.6607 - val_loss: 590.2385 - val_mae: 22.6164
# Epoch 2/100
# 21/21 - 0s - 9ms/step - loss: 486.4539 - mae: 20.2806 - val_loss: 492.8951 - val_mae: 20.5352
# Epoch 3/100
# 21/21 - 0s - 9ms/step - loss: 358.2612 - mae: 17.1536 - val_loss: 311.1600 - val_mae: 15.8748
# Epoch 4/100
# 21/21 - 0s - 9ms/step - loss: 177.9701 - mae: 11.2827 - val_loss: 117.7482 - val_mae: 8.6776
# Epoch 5/100
# 21/21 - 0s - 8ms/step - loss: 69.9275 - mae: 6.6261 - val_loss: 62.1141 - val_mae: 6.1258
# Epoch 6/100
# 21/21 - 0s - 9ms/step - loss: 43.9699 - mae: 4.9559 - val_loss: 40.5531 - val_mae: 4.9198
# Epoch 7/100
# 21/21 - 0s - 15ms/step - loss: 29.0705 - mae: 3.8032 - val_loss: 29.4465 - val_mae: 4.1431
# Epoch 8/100
# 21/21 - 0s - 8ms/step - loss: 23.0354 - mae: 3.3341 - val_loss: 25.3103 - val_mae: 3.8015
# Epoch 9/100
# 21/21 - 0s - 9ms/step - loss: 20.4037 - mae: 3.1366 - val_loss: 23.3304 - val_mae: 3.6833
# Epoch 10/100
# 21/21 - 0s - 9ms/step - loss: 18.6804 - mae: 2.9826 - val_loss: 21.8053 - val_mae: 3.5077
# Epoch 11/100
# 21/21 - 0s - 13ms/step - loss: 17.4503 - mae: 2.8699 - val_loss: 20.8079 - val_mae: 3.4216
# Epoch 12/100
# 21/21 - 0s - 11ms/step - loss: 16.3699 - mae: 2.7948 - val_loss: 19.9073 - val_mae: 3.3183
# Epoch 13/100
# 21/21 - 0s - 9ms/step - loss: 15.6799 - mae: 2.7055 - val_loss: 19.2818 - val_mae: 3.2419
# Epoch 14/100
# 21/21 - 0s - 8ms/step - loss: 14.5979 - mae: 2.6090 - val_loss: 18.6617 - val_mae: 3.1967
# Epoch 15/100
# 21/21 - 0s - 8ms/step - loss: 14.1200 - mae: 2.5643 - val_loss: 18.3461 - val_mae: 3.1782
# Epoch 16/100
# 21/21 - 0s - 8ms/step - loss: 13.4089 - mae: 2.5160 - val_loss: 17.6999 - val_mae: 3.0958
# Epoch 17/100
# 21/21 - 0s - 9ms/step - loss: 13.1259 - mae: 2.4619 - val_loss: 17.5467 - val_mae: 3.0809
# Epoch 18/100
# 21/21 - 0s - 8ms/step - loss: 12.5138 - mae: 2.4454 - val_loss: 17.1794 - val_mae: 3.0294
# Epoch 19/100
# 21/21 - 0s - 8ms/step - loss: 12.5016 - mae: 2.4170 - val_loss: 16.7431 - val_mae: 3.0206
# Epoch 20/100
# 21/21 - 0s - 8ms/step - loss: 11.9162 - mae: 2.3904 - val_loss: 16.2684 - val_mae: 2.9660
# Epoch 21/100
# 21/21 - 0s - 8ms/step - loss: 11.5982 - mae: 2.3394 - val_loss: 16.4585 - val_mae: 2.9522
# Epoch 22/100
# 21/21 - 0s - 8ms/step - loss: 11.3229 - mae: 2.3065 - val_loss: 16.1690 - val_mae: 2.9547
# Epoch 23/100
# 21/21 - 0s - 8ms/step - loss: 11.0629 - mae: 2.2873 - val_loss: 16.0160 - val_mae: 2.9491
# Epoch 24/100
# 21/21 - 0s - 18ms/step - loss: 10.7387 - mae: 2.2576 - val_loss: 15.5886 - val_mae: 2.8773
# Epoch 25/100
# 21/21 - 0s - 8ms/step - loss: 10.4299 - mae: 2.2322 - val_loss: 16.2258 - val_mae: 2.9129
# Epoch 26/100
# 21/21 - 0s - 8ms/step - loss: 10.4377 - mae: 2.1943 - val_loss: 15.6538 - val_mae: 2.8753
# Epoch 27/100
# 21/21 - 0s - 8ms/step - loss: 10.1675 - mae: 2.2105 - val_loss: 15.8912 - val_mae: 2.8741
# Epoch 28/100
# 21/21 - 0s - 8ms/step - loss: 9.9791 - mae: 2.1804 - val_loss: 15.1583 - val_mae: 2.8502
# Epoch 29/100
# 21/21 - 0s - 8ms/step - loss: 9.7716 - mae: 2.1262 - val_loss: 15.4214 - val_mae: 2.8291
# Epoch 30/100
# 21/21 - 0s - 9ms/step - loss: 9.8078 - mae: 2.1641 - val_loss: 15.1841 - val_mae: 2.8197
# Epoch 31/100
# 21/21 - 0s - 8ms/step - loss: 9.7142 - mae: 2.1715 - val_loss: 15.7498 - val_mae: 2.9168
# Epoch 32/100
# 21/21 - 0s - 8ms/step - loss: 10.5499 - mae: 2.3546 - val_loss: 15.5356 - val_mae: 2.8765
# Epoch 33/100
# 21/21 - 0s - 8ms/step - loss: 9.3174 - mae: 2.1311 - val_loss: 15.0021 - val_mae: 2.8581
# Epoch 34/100
# 21/21 - 0s - 8ms/step - loss: 9.4729 - mae: 2.1083 - val_loss: 15.2786 - val_mae: 2.8512
# Epoch 35/100
# 21/21 - 0s - 9ms/step - loss: 8.9984 - mae: 2.0931 - val_loss: 14.9842 - val_mae: 2.8400
# Epoch 36/100
# 21/21 - 0s - 8ms/step - loss: 8.7769 - mae: 2.0670 - val_loss: 15.1771 - val_mae: 2.9028
# Epoch 37/100
# 21/21 - 0s - 8ms/step - loss: 8.8106 - mae: 2.0649 - val_loss: 14.8903 - val_mae: 2.8171
# Epoch 38/100
# 21/21 - 0s - 8ms/step - loss: 8.8334 - mae: 2.1028 - val_loss: 14.7971 - val_mae: 2.8114
# Epoch 39/100
# 21/21 - 0s - 18ms/step - loss: 8.6418 - mae: 2.0432 - val_loss: 15.8432 - val_mae: 2.8862
# Epoch 40/100
# 21/21 - 0s - 8ms/step - loss: 8.8853 - mae: 2.0855 - val_loss: 16.5920 - val_mae: 2.8257
# Epoch 41/100
# 21/21 - 0s - 8ms/step - loss: 9.3724 - mae: 2.2535 - val_loss: 16.3943 - val_mae: 3.0173
# Epoch 42/100
# 21/21 - 0s - 9ms/step - loss: 8.6161 - mae: 2.0854 - val_loss: 15.1050 - val_mae: 2.8461
# Epoch 43/100
# 21/21 - 0s - 8ms/step - loss: 8.2439 - mae: 2.0285 - val_loss: 15.0180 - val_mae: 2.8559
# Epoch 44/100
# 21/21 - 0s - 9ms/step - loss: 8.4045 - mae: 2.0167 - val_loss: 14.6756 - val_mae: 2.8370
# Epoch 45/100
# 21/21 - 0s - 9ms/step - loss: 8.0166 - mae: 1.9914 - val_loss: 14.8209 - val_mae: 2.8119
# Epoch 46/100
# 21/21 - 0s - 9ms/step - loss: 8.0078 - mae: 1.9862 - val_loss: 15.0162 - val_mae: 2.8550
# Epoch 47/100
# 21/21 - 0s - 16ms/step - loss: 8.1051 - mae: 2.0321 - val_loss: 14.2771 - val_mae: 2.7050
# Epoch 48/100
# 21/21 - 0s - 8ms/step - loss: 8.3140 - mae: 2.0876 - val_loss: 14.4725 - val_mae: 2.7436
# Epoch 49/100
# 21/21 - 0s - 8ms/step - loss: 7.7791 - mae: 1.9507 - val_loss: 14.3558 - val_mae: 2.7874
# Epoch 50/100
# 21/21 - 0s - 9ms/step - loss: 7.6915 - mae: 1.9616 - val_loss: 14.9110 - val_mae: 2.8009
# Epoch 51/100
# 21/21 - 0s - 8ms/step - loss: 7.6511 - mae: 1.9280 - val_loss: 14.2979 - val_mae: 2.7222
# Epoch 52/100
# 21/21 - 0s - 8ms/step - loss: 7.5404 - mae: 1.9423 - val_loss: 14.1868 - val_mae: 2.7168
# Epoch 53/100
# 21/21 - 0s - 8ms/step - loss: 7.4956 - mae: 1.9354 - val_loss: 14.5095 - val_mae: 2.7256
# Epoch 54/100
# 21/21 - 0s - 9ms/step - loss: 7.4417 - mae: 1.8978 - val_loss: 14.3520 - val_mae: 2.7338
# Epoch 55/100
# 21/21 - 0s - 17ms/step - loss: 7.6732 - mae: 1.9811 - val_loss: 14.2116 - val_mae: 2.7568
# Epoch 56/100
# 21/21 - 0s - 8ms/step - loss: 7.4964 - mae: 1.9151 - val_loss: 14.1141 - val_mae: 2.7317
# Epoch 57/100
# 21/21 - 0s - 8ms/step - loss: 7.2895 - mae: 1.8966 - val_loss: 13.4069 - val_mae: 2.7300
# Epoch 58/100
# 21/21 - 0s - 8ms/step - loss: 7.2357 - mae: 1.8506 - val_loss: 13.5858 - val_mae: 2.6430
# Epoch 59/100
# 21/21 - 0s - 9ms/step - loss: 7.1223 - mae: 1.8939 - val_loss: 14.7542 - val_mae: 2.7520
# Epoch 60/100
# 21/21 - 0s - 8ms/step - loss: 6.9425 - mae: 1.8792 - val_loss: 14.0584 - val_mae: 2.6846
# Epoch 61/100
# 21/21 - 0s - 9ms/step - loss: 7.1158 - mae: 1.9097 - val_loss: 13.9708 - val_mae: 2.7052
# Epoch 62/100
# 21/21 - 0s - 9ms/step - loss: 7.0200 - mae: 1.8372 - val_loss: 14.2063 - val_mae: 2.6179
# Epoch 63/100
# 21/21 - 0s - 9ms/step - loss: 6.8178 - mae: 1.8424 - val_loss: 13.9198 - val_mae: 2.6885
# Epoch 64/100
# 21/21 - 0s - 9ms/step - loss: 7.1097 - mae: 1.8711 - val_loss: 15.1027 - val_mae: 2.8559
# Epoch 65/100
# 21/21 - 0s - 10ms/step - loss: 7.1780 - mae: 1.8849 - val_loss: 14.5598 - val_mae: 2.7014
# Epoch 66/100
# 21/21 - 0s - 8ms/step - loss: 6.7728 - mae: 1.8422 - val_loss: 14.3164 - val_mae: 2.6504
# Epoch 67/100
# 21/21 - 0s - 8ms/step - loss: 7.0790 - mae: 1.8379 - val_loss: 14.4001 - val_mae: 2.5918
# Epoch 68/100
# 21/21 - 0s - 8ms/step - loss: 6.7666 - mae: 1.8768 - val_loss: 15.9897 - val_mae: 2.7514
# Epoch 69/100
# 21/21 - 0s - 8ms/step - loss: 6.7396 - mae: 1.8301 - val_loss: 16.0598 - val_mae: 2.7727
# Epoch 70/100
# 21/21 - 0s - 17ms/step - loss: 6.6971 - mae: 1.8221 - val_loss: 14.2785 - val_mae: 2.6724
# Epoch 71/100
# 21/21 - 0s - 8ms/step - loss: 6.3926 - mae: 1.7875 - val_loss: 14.3774 - val_mae: 2.6446
# Epoch 72/100
# 21/21 - 0s - 8ms/step - loss: 6.4640 - mae: 1.7919 - val_loss: 14.5389 - val_mae: 2.6438
# Epoch 73/100
# 21/21 - 0s - 9ms/step - loss: 6.2837 - mae: 1.7636 - val_loss: 14.2795 - val_mae: 2.6986
# Epoch 74/100
# 21/21 - 0s - 8ms/step - loss: 6.2983 - mae: 1.7671 - val_loss: 14.5406 - val_mae: 2.6116
# Epoch 75/100
# 21/21 - 0s - 9ms/step - loss: 6.2895 - mae: 1.7816 - val_loss: 15.0839 - val_mae: 2.7386
# Epoch 76/100
# 21/21 - 0s - 9ms/step - loss: 6.1909 - mae: 1.7375 - val_loss: 14.6512 - val_mae: 2.6439
# Epoch 77/100
# 21/21 - 0s - 8ms/step - loss: 6.1405 - mae: 1.7609 - val_loss: 14.6338 - val_mae: 2.6954
# Epoch 78/100
# 21/21 - 0s - 8ms/step - loss: 6.2187 - mae: 1.7550 - val_loss: 14.5551 - val_mae: 2.6186
# Epoch 79/100
# 21/21 - 0s - 8ms/step - loss: 6.2204 - mae: 1.7529 - val_loss: 15.0067 - val_mae: 2.6512
# Epoch 80/100
# 21/21 - 0s - 9ms/step - loss: 6.0951 - mae: 1.7387 - val_loss: 14.5423 - val_mae: 2.6314
# Epoch 81/100
# 21/21 - 0s - 8ms/step - loss: 5.9542 - mae: 1.7156 - val_loss: 14.9176 - val_mae: 2.6674
# Epoch 82/100
# 21/21 - 0s - 8ms/step - loss: 5.9508 - mae: 1.7111 - val_loss: 14.6609 - val_mae: 2.6508
# Epoch 83/100
# 21/21 - 0s - 8ms/step - loss: 5.9273 - mae: 1.7299 - val_loss: 14.8327 - val_mae: 2.7224
# Epoch 84/100
# 21/21 - 0s - 8ms/step - loss: 5.8334 - mae: 1.7139 - val_loss: 14.1301 - val_mae: 2.5769
# Epoch 85/100
# 21/21 - 0s - 8ms/step - loss: 5.6968 - mae: 1.6832 - val_loss: 14.6025 - val_mae: 2.6163
# Epoch 86/100
# 21/21 - 0s - 9ms/step - loss: 5.6593 - mae: 1.6756 - val_loss: 14.4485 - val_mae: 2.5997
# Epoch 87/100
# 21/21 - 0s - 8ms/step - loss: 5.6884 - mae: 1.6668 - val_loss: 14.4539 - val_mae: 2.6477
# Epoch 88/100
# 21/21 - 0s - 9ms/step - loss: 5.6521 - mae: 1.6657 - val_loss: 14.1949 - val_mae: 2.5884
# Epoch 89/100
# 21/21 - 0s - 9ms/step - loss: 5.8203 - mae: 1.6778 - val_loss: 14.5153 - val_mae: 2.5752
# Epoch 90/100
# 21/21 - 0s - 9ms/step - loss: 5.8730 - mae: 1.7334 - val_loss: 14.8912 - val_mae: 2.6838
# Epoch 91/100
# 21/21 - 0s - 9ms/step - loss: 5.5764 - mae: 1.6896 - val_loss: 14.4243 - val_mae: 2.6121
# Epoch 92/100
# 21/21 - 0s - 9ms/step - loss: 5.6628 - mae: 1.6723 - val_loss: 14.5189 - val_mae: 2.5903
# Epoch 93/100
# 21/21 - 0s - 9ms/step - loss: 5.5847 - mae: 1.6737 - val_loss: 14.6860 - val_mae: 2.6049
# Epoch 94/100
# 21/21 - 0s - 9ms/step - loss: 5.5537 - mae: 1.6679 - val_loss: 14.0781 - val_mae: 2.5992
# Epoch 95/100
# 21/21 - 0s - 8ms/step - loss: 5.4621 - mae: 1.6442 - val_loss: 14.1047 - val_mae: 2.5736
# Epoch 96/100
# 21/21 - 0s - 8ms/step - loss: 5.3343 - mae: 1.6579 - val_loss: 14.8524 - val_mae: 2.5695
# Epoch 97/100
# 21/21 - 0s - 8ms/step - loss: 5.2847 - mae: 1.6059 - val_loss: 14.5388 - val_mae: 2.5965
# Epoch 98/100
# 21/21 - 0s - 9ms/step - loss: 5.2897 - mae: 1.6248 - val_loss: 14.1365 - val_mae: 2.6153
# Epoch 99/100
# 21/21 - 0s - 8ms/step - loss: 5.2485 - mae: 1.6124 - val_loss: 13.9836 - val_mae: 2.5398
# Epoch 100/100
# 21/21 - 0s - 8ms/step - loss: 5.1414 - mae: 1.6072 - val_loss: 14.1476 - val_mae: 2.5583

# %% [markdown]
# ### 9. Model Prediction (New Observation)

# %%
# Example new data (13 features)
new_data = np.array([[0.02, 18, 2.5, 0, 0.45, 6.5, 65, 4.5, 1, 300, 15, 390, 5]])

# Apply same scaling
new_data = scaler.transform(new_data)

# Predict
prediction = model.predict(new_data)

print("Predicted House Price:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Predicted House Price: [[28.188242]]

# %% [markdown]
# # THE END!
